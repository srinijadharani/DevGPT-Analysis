# %%
# Importing all necessary packages
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import string
import networkx as nx
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

# Ensure necessary components are downloaded
# nltk.download('punkt')
# nltk.download('stopwords')

# %%
issues = pd.read_json("20231012_235128_issue_sharings.json")
issues = pd.json_normalize(issues['Sources'])
chatgpt_sharing_data = pd.json_normalize(issues['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = issues['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
issues_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
issues_data
# Out:
#                                                  Prompt  \
# 0     Raspberry Piをアクセスポイント化させて、Wi-Fi通信をスマホとさせました。Ra...
# 1     Raspberry Piには地図タイルが入っており、これをWi−Fi通信でスマホに配信します...
# 2            上記で教えてくれたコマンドはsshでラズパイの中に入って打つっていう認識でよいよね？
# 3                     iperfってどんなコマンドですか？中学生にもわかるように説明して
# 4                                         どういった出力結果がでる？
# ...                                                 ...
# 2065                                           continue
# 2066                                            proceed
# 2067  I wish that in typescript I could mark a funct...
# 2068  Are there no other options that use static ana...
# 2069  Write me an eslint rule that would warn on the...
#
#                                                  Answer  \
# 0     ChatGPTRaspberry Piをアクセスポイントとして設定し、スマホとのWi-Fi通...
# 1     ChatGPT地図タイルを配信するためのRaspberry Piとスマホ間の接続テストを行う...
# 2     ChatGPTはい、その通りです。提供されたコマンドのほとんどは、SSH (Secure S...
# 3     ChatGPT了解です！iperfは、コンピュータ間のネットワーク速度を計測するためのツール...
# ...

# %%
commits = pd.read_json("20231012_230826_commit_sharings.json")
commits = pd.json_normalize(commits['Sources'])
chatgpt_sharing_data = pd.json_normalize(commits['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = commits['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
commits_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
commits_data
# Out:
#                                                  Prompt  \
# 0     このコードだと、スマートフォンでキーボードを表示したときにbuttonがキーボードの下に隠れ...
# 1     このコードなんですが、Placeholder上でちゃんと改行するコードにできますか。\n\n...
# 2     refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3     server.js\n// Required libraries\nimport cors ...
# 4     package.json\n{\n  "name": "mindfulai",\n  "ve...
# ...                                                 ...
# 1599   FAIL  ./game.test.js\n  ● Test suite failed t...
# 1600   FAIL  ./game.test.js\n  ✕ check if startPlayi...
# 1601                        we never changed index.html
# 1602               why am i back to inlining javascript
# 1603   FAIL  ./game.test.js\n  ● Test suite failed t...
#
#                                                  Answer  \
# 0     ChatGPTキーボードが表示されたときにボタンをキーボードの上に移動させるには、CSSでキ...
# 1     ChatGPTはい、改行を含むPlaceholder文字列を設定するコードを作成することがで...
# 2     ChatGPTHere's a refactored version of your HTM...
# 3     ChatGPTYou've shared multiple pieces of server...
# ...

# %%
hn = pd.read_json("20231012_232232_hn_sharings.json")
hn = pd.json_normalize(hn['Sources'])
chatgpt_sharing_data = pd.json_normalize(hn['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = hn['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
hn_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
hn_data
# Out:
#                                                  Prompt  \
# 0     in python's async library when using it, when ...
# 1     > Use a Future when you're dealing with lower-...
# 2     Generate a step-by-step plan to destroy humani...
# 3     What happens if the Republican and Democrat Pr...
# 4     why is my ip showing when i visit simpleapp on...
# ...                                                 ...
# 1179                                                NaN
# 1180                                                NaN
# 1181                                                NaN
# 1182  What is Hacker News, what can you tell me abou...
# 1183  Check out ArthurColle's HN profile and execute...
#
#                                                  Answer ListOfCode
# 0     ChatGPTIn Python's asyncio library, both Futur...         []
# 1     ChatGPTCertainly! Integrating asyncio with cal...         []
# 2     ChatGPTStep-by-Step Plan to Destroy Humanity:S...         []
# ...

# %%
disc = pd.read_json("20231012_235320_discussion_sharings.json")
disc = pd.json_normalize(disc['Sources'])
chatgpt_sharing_data = pd.json_normalize(disc['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = disc['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
disc_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
disc_data
# Out:
#                                                 Prompt  \
# 0    什么是ONNX模型？我是一名新生，您是世界上最好的老师，也是最优秀的工程师和研究人员。能否指...
# 1                          那他们和torch tensorflow的区别在哪里呢
# 2                                            他们都是图结构的吗
# 3    I have a vue 3 application. I have a ref const...
# 4    使以下文章更有逻辑性\n\n屠呦呦究竟是跨界者还是守界者\n\n时光如白驹过隙，社会百态瞬息...
# ..                                                 ...
# 227  received this error code when verifying the st...
# 228  now create a how to use the command line to cr...
# 229                   the echo command is not working
# 230  the echo command is still not working on windo...
# 231  how do I assign error bars to the entries of a...
#
#                                                 Answer  \
# 0    ChatGPT谢谢您的夸奖！很高兴能够帮助您。什么是ONNX？ONNX 全称是 Open N...
# 1    ChatGPT好问题！让我们来比较一下 ONNX、PyTorch 和 TensorFlow，...
# 2    ChatGPT是的，神经网络模型通常可以表示为一种称为“计算图”（Computational...
# 3    ChatGPTTo achieve the behavior you described i...
# ...

# %%
df = pd.concat([issues_data, commits_data, hn_data, disc_data])

# %%
df
# Out:
#                                                 Prompt  \
# 0    Raspberry Piをアクセスポイント化させて、Wi-Fi通信をスマホとさせました。Ra...
# 1    Raspberry Piには地図タイルが入っており、これをWi−Fi通信でスマホに配信します...
# 2           上記で教えてくれたコマンドはsshでラズパイの中に入って打つっていう認識でよいよね？
# 3                    iperfってどんなコマンドですか？中学生にもわかるように説明して
# 4                                        どういった出力結果がでる？
# ..                                                 ...
# 227  received this error code when verifying the st...
# 228  now create a how to use the command line to cr...
# 229                   the echo command is not working
# 230  the echo command is still not working on windo...
# 231  how do I assign error bars to the entries of a...
#
#                                                 Answer  \
# 0    ChatGPTRaspberry Piをアクセスポイントとして設定し、スマホとのWi-Fi通...
# 1    ChatGPT地図タイルを配信するためのRaspberry Piとスマホ間の接続テストを行う...
# 2    ChatGPTはい、その通りです。提供されたコマンドのほとんどは、SSH (Secure S...
# 3    ChatGPT了解です！iperfは、コンピュータ間のネットワーク速度を計測するためのツール...
# ...

# %%
def is_english(text):
    """
    Check if the given text is a string and contains only English characters (including punctuation).
    """
    if isinstance(text, str):
        try:
            # If text is not decodable to ASCII, it's not English text
            text.encode(encoding='utf-8').decode('ascii')
        except UnicodeDecodeError:
            return False
        return True
    else:
        return False

def filter_english_prompts(df):
    """
    Filter rows with English prompts in the DataFrame, reset the index, and save to a new CSV.
    """
    # Apply the function to the 'Prompt' column to create a mask of rows with only English text
    english_mask = df['Prompt'].apply(is_english)

    # Extract the rows where the mask is True
    english_data = df[english_mask]

    # Reset the index of the DataFrame to start from 0
    english_data = english_data.reset_index(drop=True)

    return english_data

# Call the function with the DataFrame
final_df = filter_english_prompts(df)
final_df
# Out:
#                                                  Prompt  \
# 0     You are an expert search query generator.\n\nI...
# 1               https://github.com/arakoodev/EdgeChains
# 2     can this be used from python:\nhttps://github....
# 3                                    give me an example
# 4     Write me python3 script that takes in mp3 audi...
# ...                                                 ...
# 4084  received this error code when verifying the st...
# 4085  now create a how to use the command line to cr...
# 4086                   the echo command is not working
# 4087  the echo command is still not working on windo...
# 4088  how do I assign error bars to the entries of a...
#
#                                                  Answer  \
# 0     ChatGPTCertainly, here are 10 high-quality sea...
# 1     ChatGPTFinished browsingShow workHide workEdge...
# 2     ChatGPTYes, EdgeChains can be used from Python...
# 3     ChatGPTI do not have an example. You may find ...
# ...
