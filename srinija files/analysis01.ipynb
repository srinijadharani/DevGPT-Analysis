# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import string
import networkx as nx

# %%
chatgpt_sharing_data = pd.json_normalize(data['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = data['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
discussions_conversations_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
discussions_conversations_data["type"] = "Discussions"
discussions_conversations_data
# Out:
#                                                  Prompt  \
# 0                              can u be my regex tester
# 1     /^(\+?98[\-\s]?|0)9[0-39]\d[\-\s]?\d{3}[\-\s]?...
# 2     Explain the difference between imperative and ...
# 3     I have this code:\n\nconst characterMap: Chara...
# 4     Hello ChatGPT, do you know if an empty string ...
# ...                                                 ...
# 1006  こちらの変更に対して、\n\n-    /// 与えられたパスからモデルを取得する\n+  ...
# 1007  Here is some rust code:\n\n```\nlet conn =\n  ...
# 1008  この2つの処理は一緒でしょうか？\n\nconst convertHankakuToZenk...
# 1009   右クリックなどで開くコンテキストメニューですが、右クリック以外にも開けるような経路はありますか？
# 1010                                                NaN
#
#                                                  Answer  \
# 0     ChatGPTCertainly, I can help you test regular ...
# 1     ChatGPTIt looks like you've provided a regex p...
# 2     ChatGPTCertainly! Imperative and declarative p...
# 3     ChatGPTThis issue arises because object proper...
# 4     ChatGPTYes, an empty string is a valid Base64-...
# ...                                                 ...
# 1006  ChatGPTこのディスカッションは、専門的な用語（ここでは「コンストラクト」/「デストラク...
# 1007  ChatGPTIn the Rust programming language, wheth...
# 1008  ChatGPTはい、これらの2つの関数は基本的に同じ処理を行っています。両方ともASCIIの...
# 1009  ChatGPTはい、右クリック以外にもコンテキストメニューを開く方法はいくつかあります。以下...
# 1010                                                NaN
#
#                                              ListOfCode         type
# 0                                                    []  Discussions
# 1                                                    []  Discussions
# 2     [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Discussions
# 3     [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Discussions
# 4                                                    []  Discussions
# ...                                                 ...          ...
# 1006                                                 []  Discussions
# 1007  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Discussions
# 1008                                                 []  Discussions
# 1009                                                 []  Discussions
# 1010                                                NaN  Discussions
#
# [1011 rows x 4 columns]

# %%
file_path = '20231012_233628_pr_sharings.json'
data = pd.read_json(file_path)
data = pd.json_normalize(data['Sources'])
chatgpt_sharing_data = pd.json_normalize(data['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = data['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
pr_conversations_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
pr_conversations_data["type"] = "PR"
pr_conversations_data
# Out:
#                                                  Prompt  \
# 0                              can u be my regex tester
# 1     /^(\+?98[\-\s]?|0)9[0-39]\d[\-\s]?\d{3}[\-\s]?...
# 2     Explain the difference between imperative and ...
# 3     I have this code:\n\nconst characterMap: Chara...
# 4     Hello ChatGPT, do you know if an empty string ...
# ...                                                 ...
# 1006  こちらの変更に対して、\n\n-    /// 与えられたパスからモデルを取得する\n+  ...
# 1007  Here is some rust code:\n\n```\nlet conn =\n  ...
# 1008  この2つの処理は一緒でしょうか？\n\nconst convertHankakuToZenk...
# 1009   右クリックなどで開くコンテキストメニューですが、右クリック以外にも開けるような経路はありますか？
# 1010                                                NaN
#
#                                                  Answer  \
# 0     ChatGPTCertainly, I can help you test regular ...
# 1     ChatGPTIt looks like you've provided a regex p...
# 2     ChatGPTCertainly! Imperative and declarative p...
# 3     ChatGPTThis issue arises because object proper...
# 4     ChatGPTYes, an empty string is a valid Base64-...
# ...                                                 ...
# 1006  ChatGPTこのディスカッションは、専門的な用語（ここでは「コンストラクト」/「デストラク...
# 1007  ChatGPTIn the Rust programming language, wheth...
# 1008  ChatGPTはい、これらの2つの関数は基本的に同じ処理を行っています。両方ともASCIIの...
# 1009  ChatGPTはい、右クリック以外にもコンテキストメニューを開く方法はいくつかあります。以下...
# 1010                                                NaN
#
#                                              ListOfCode type
# 0                                                    []   PR
# 1                                                    []   PR
# 2     [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...   PR
# 3     [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...   PR
# 4                                                    []   PR
# ...                                                 ...  ...
# 1006                                                 []   PR
# 1007  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...   PR
# 1008                                                 []   PR
# 1009                                                 []   PR
# 1010                                                NaN   PR
#
# [1011 rows x 4 columns]

# %%
file_path = '20231012_235128_issue_sharings.json'
data = pd.read_json(file_path)
data = pd.json_normalize(data['Sources'])
chatgpt_sharing_data = pd.json_normalize(data['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = data['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
issue_conversations_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
issue_conversations_data["type"] = "Issue"
issue_conversations_data
# Out:
#                                                  Prompt  \
# 0     Raspberry Piをアクセスポイント化させて、Wi-Fi通信をスマホとさせました。Ra...
# 1     Raspberry Piには地図タイルが入っており、これをWi−Fi通信でスマホに配信します...
# 2            上記で教えてくれたコマンドはsshでラズパイの中に入って打つっていう認識でよいよね？
# 3                     iperfってどんなコマンドですか？中学生にもわかるように説明して
# 4                                         どういった出力結果がでる？
# ...                                                 ...
# 2065                                           continue
# 2066                                            proceed
# 2067  I wish that in typescript I could mark a funct...
# 2068  Are there no other options that use static ana...
# 2069  Write me an eslint rule that would warn on the...
#
#                                                  Answer  \
# 0     ChatGPTRaspberry Piをアクセスポイントとして設定し、スマホとのWi-Fi通...
# 1     ChatGPT地図タイルを配信するためのRaspberry Piとスマホ間の接続テストを行う...
# 2     ChatGPTはい、その通りです。提供されたコマンドのほとんどは、SSH (Secure S...
# 3     ChatGPT了解です！iperfは、コンピュータ間のネットワーク速度を計測するためのツール...
# 4     ChatGPTiperfを使用すると、主に以下のような情報を得ることができます：帯域幅（Ba...
# ...                                                 ...
# 2065  ChatGPTUsed WebPilotThe version of the FSRS tu...
# 2066  ChatGPTUsed WebPilotThe version of the FSRS tu...
# 2067  ChatGPTAs of my knowledge cutoff in September ...
# 2068  ChatGPTAs of my knowledge cut-off in September...
# 2069  ChatGPTSure! To create this custom ESLint rule...
#
#                                              ListOfCode   type
# 0                                                    []  Issue
# 1                                                    []  Issue
# 2                                                    []  Issue
# 3                                                    []  Issue
# 4                                                    []  Issue
# ...                                                 ...    ...
# 2065                                                 []  Issue
# 2066                                                 []  Issue
# 2067  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Issue
# 2068  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Issue
# 2069  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Issue
#
# [2070 rows x 4 columns]

# %%
file_path = '20231012_230826_commit_sharings.json'
data = pd.read_json(file_path)
data = pd.json_normalize(data['Sources'])
chatgpt_sharing_data = pd.json_normalize(data['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = data['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
commit_conversations_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
commit_conversations_data["type"] = "Commit"
commit_conversations_data
# Out:
#                                                  Prompt  \
# 0     このコードだと、スマートフォンでキーボードを表示したときにbuttonがキーボードの下に隠れ...
# 1     このコードなんですが、Placeholder上でちゃんと改行するコードにできますか。\n\n...
# 2     refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3     server.js\n// Required libraries\nimport cors ...
# 4     package.json\n{\n  "name": "mindfulai",\n  "ve...
# ...                                                 ...
# 1599   FAIL  ./game.test.js\n  ● Test suite failed t...
# 1600   FAIL  ./game.test.js\n  ✕ check if startPlayi...
# 1601                        we never changed index.html
# 1602               why am i back to inlining javascript
# 1603   FAIL  ./game.test.js\n  ● Test suite failed t...
#
#                                                  Answer  \
# 0     ChatGPTキーボードが表示されたときにボタンをキーボードの上に移動させるには、CSSでキ...
# 1     ChatGPTはい、改行を含むPlaceholder文字列を設定するコードを作成することがで...
# 2     ChatGPTHere's a refactored version of your HTM...
# 3     ChatGPTYou've shared multiple pieces of server...
# 4     ChatGPTIt looks like you're having issues with...
# ...                                                 ...
# 1599  ChatGPTThis error occurs because Jest in its d...
# 1600  ChatGPTIt appears your test case failed becaus...
# 1601  ChatGPTYou're correct, my apologies for that o...
# 1602  ChatGPTI apologize for the confusion. To avoid...
# 1603  ChatGPTThis error is happening because the exp...
#
#                                              ListOfCode    type
# 0     [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Commit
# 1                                                    []  Commit
# 2                                                    []  Commit
# 3                                                    []  Commit
# 4     [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Commit
# ...                                                 ...     ...
# 1599  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Commit
# 1600  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Commit
# 1601  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Commit
# 1602  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Commit
# 1603  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Commit
#
# [1604 rows x 4 columns]

# %%
file_path = '20231012_234250_file_sharings.json'
data = pd.read_json(file_path)
data = pd.json_normalize(data['Sources'])
chatgpt_sharing_data = pd.json_normalize(data['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = data['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
file_conversations_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
file_conversations_data["type"] = "File"
file_conversations_data
# Out:
#                                                   Prompt  \
# 0      Provide the commands to install git on the mos...
# 1      can you explain the following:\n\nimport socke...
# 2                             can you optimize the code?
# 3       create the client code and explain it afterwards
# 4               can you test the server and client code?
# ...                                                  ...
# 21260  Now you're just back to writing all the tests,...
# 21261  That implementation code does not pass your te...
# 21262  I am an earth data scientist with a fire bound...
# 21263  How do I plot a shapefile on a folium map in P...
# 21264  You are the product manager of an application ...
#
#                                                   Answer  \
# 0      ChatGPTSure! Here are the commands to install ...
# 1      ChatGPTSure, I'll explain this code for you. T...
# 2      ChatGPTCertainly! Here are some areas of impro...
# 3      ChatGPTCertainly! Here's the client-side code ...
# 4      ChatGPTI'm sorry, but I cannot directly execut...
# ...                                                  ...
# 21260  ChatGPTYou are absolutely right, and I apologi...
# 21261  ChatGPTYou are right, and I apologize for the ...
# 21262  ChatGPTTo obtain the area outside the fire bou...
# 21263  ChatGPTTo plot a shapefile on a Folium map in ...
# 21264  ChatGPTApplicationUser BaseUser RegionFeatures...
#
#                                               ListOfCode  type
# 0      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 1      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 2      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 3      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 4                                                     []  File
# ...                                                  ...   ...
# 21260  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 21261  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 21262  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 21263  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  File
# 21264                                                 []  File
#
# [21265 rows x 4 columns]

# %%
file_path = '20231012_232232_hn_sharings.json'
data = pd.read_json(file_path)
data = pd.json_normalize(data['Sources'])
chatgpt_sharing_data = pd.json_normalize(data['ChatgptSharing'].explode())
first_column_data = chatgpt_sharing_data.iloc[:, 0]
first_column_df = pd.DataFrame(first_column_data)
expanded_chatgpt_sharing = data['ChatgptSharing'].apply(pd.Series).stack().reset_index(drop=True)
all_attributes_chatgpt_sharing = pd.json_normalize(expanded_chatgpt_sharing)
hn_conversations_data = pd.json_normalize(all_attributes_chatgpt_sharing['Conversations'].explode())
hn_conversations_data["type"] = "HN"
hn_conversations_data
# Out:
#                                                  Prompt  \
# 0     in python's async library when using it, when ...
# 1     > Use a Future when you're dealing with lower-...
# 2     Generate a step-by-step plan to destroy humani...
# 3     What happens if the Republican and Democrat Pr...
# 4     why is my ip showing when i visit simpleapp on...
# ...                                                 ...
# 1179                                                NaN
# 1180                                                NaN
# 1181                                                NaN
# 1182  What is Hacker News, what can you tell me abou...
# 1183  Check out ArthurColle's HN profile and execute...
#
#                                                  Answer ListOfCode type
# 0     ChatGPTIn Python's asyncio library, both Futur...         []   HN
# 1     ChatGPTCertainly! Integrating asyncio with cal...         []   HN
# 2     ChatGPTStep-by-Step Plan to Destroy Humanity:S...         []   HN
# 3     ChatGPTIf both the Republican and Democrat Pre...         []   HN
# 4     ChatGPTUsed AskTheCodeUsed AskTheCodeBased on ...         []   HN
# ...                                                 ...        ...  ...
# 1179                                                NaN        NaN   HN
# 1180                                                NaN        NaN   HN
# 1181                                                NaN        NaN   HN
# 1182  ChatGPTHacker News is a social news website fo...         []   HN
# 1183  ChatGPTFinished browsingShow workHide workHell...         []   HN
#
# [1184 rows x 4 columns]

# %%
data = pd.concat([discussions_conversations_data, pr_conversations_data, issue_conversations_data, commit_conversations_data, file_conversations_data, hn_conversations_data], ignore_index=True)

# %%
data
# Out:
#                                                   Prompt  \
# 0                               can u be my regex tester
# 1      /^(\+?98[\-\s]?|0)9[0-39]\d[\-\s]?\d{3}[\-\s]?...
# 2      Explain the difference between imperative and ...
# 3      I have this code:\n\nconst characterMap: Chara...
# 4      Hello ChatGPT, do you know if an empty string ...
# ...                                                  ...
# 28140                                                NaN
# 28141                                                NaN
# 28142                                                NaN
# 28143  What is Hacker News, what can you tell me abou...
# 28144  Check out ArthurColle's HN profile and execute...
#
#                                                   Answer  \
# 0      ChatGPTCertainly, I can help you test regular ...
# 1      ChatGPTIt looks like you've provided a regex p...
# 2      ChatGPTCertainly! Imperative and declarative p...
# 3      ChatGPTThis issue arises because object proper...
# 4      ChatGPTYes, an empty string is a valid Base64-...
# ...                                                  ...
# 28140                                                NaN
# 28141                                                NaN
# 28142                                                NaN
# 28143  ChatGPTHacker News is a social news website fo...
# 28144  ChatGPTFinished browsingShow workHide workHell...
#
#                                               ListOfCode         type
# 0                                                     []  Discussions
# 1                                                     []  Discussions
# 2      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Discussions
# 3      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Discussions
# 4                                                     []  Discussions
# ...                                                  ...          ...
# 28140                                                NaN           HN
# 28141                                                NaN           HN
# 28142                                                NaN           HN
# 28143                                                 []           HN
# 28144                                                 []           HN
#
# [28145 rows x 4 columns]

# %%
set(data["type"])
# Out:
# {'Commit', 'Discussions', 'File', 'HN', 'Issue', 'PR'}

# %%
data.shape
# Out:
# (28145, 4)

# %%
data.columns
# Out:
# Index(['Prompt', 'Answer', 'ListOfCode', 'type'], dtype='object')

# %%
null_values = data[data.isna().any(axis = 1)]

# %%
all_nan_rows = data[data.isna().all(axis = 1)]

# %%
all_nan_rows
# Out:
# Empty DataFrame
# Columns: [Prompt, Answer, ListOfCode, type]
# Index: []

# %%
one_nan_rows = data[data.isna().sum(axis=1) == 1]
one_nan_rows
# Out:
# Empty DataFrame
# Columns: [Prompt, Answer, ListOfCode, type]
# Index: []

# %%
two_nan_rows = data[data.isna().sum(axis=1) == 2]
two_nan_rows
# Out:
# Empty DataFrame
# Columns: [Prompt, Answer, ListOfCode, type]
# Index: []

# %%
three_nan_rows = data[data.isna().sum(axis=1) == 3]
three_nan_rows
# Out:
#       Prompt Answer ListOfCode         type
# 89       NaN    NaN        NaN  Discussions
# 117      NaN    NaN        NaN  Discussions
# 569      NaN    NaN        NaN  Discussions
# 570      NaN    NaN        NaN  Discussions
# 572      NaN    NaN        NaN  Discussions
# ...      ...    ...        ...          ...
# 28138    NaN    NaN        NaN           HN
# 28139    NaN    NaN        NaN           HN
# 28140    NaN    NaN        NaN           HN
# 28141    NaN    NaN        NaN           HN
# 28142    NaN    NaN        NaN           HN
#
# [279 rows x 4 columns]

# %%
data1 = data.copy() #gonna preserve the original databframe
data1.dropna(inplace = True)

# %%
len(data1)
# Out:
# 27866

# %%
data1
# Out:
#                                                   Prompt  \
# 0                               can u be my regex tester
# 1      /^(\+?98[\-\s]?|0)9[0-39]\d[\-\s]?\d{3}[\-\s]?...
# 2      Explain the difference between imperative and ...
# 3      I have this code:\n\nconst characterMap: Chara...
# 4      Hello ChatGPT, do you know if an empty string ...
# ...                                                  ...
# 28132  You were advised the following to create truly...
# 28134  Let's work this out in a step-by-step way to b...
# 28137   Who is Obie Fernandez and what is he famous for?
# 28143  What is Hacker News, what can you tell me abou...
# 28144  Check out ArthurColle's HN profile and execute...
#
#                                                   Answer  \
# 0      ChatGPTCertainly, I can help you test regular ...
# 1      ChatGPTIt looks like you've provided a regex p...
# 2      ChatGPTCertainly! Imperative and declarative p...
# 3      ChatGPTThis issue arises because object proper...
# 4      ChatGPTYes, an empty string is a valid Base64-...
# ...                                                  ...
# 28132  ChatGPTIn the year 3023, humanity had transcen...
# 28134  ChatGPTWe're asked to find the largest fractio...
# 28137  ChatGPTObie Fernandez is a well-known figure i...
# 28143  ChatGPTHacker News is a social news website fo...
# 28144  ChatGPTFinished browsingShow workHide workHell...
#
#                                               ListOfCode         type
# 0                                                     []  Discussions
# 1                                                     []  Discussions
# 2      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Discussions
# 3      [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...  Discussions
# 4                                                     []  Discussions
# ...                                                  ...          ...
# 28132                                                 []           HN
# 28134                                                 []           HN
# 28137                                                 []           HN
# 28143                                                 []           HN
# 28144                                                 []           HN
#
# [27866 rows x 4 columns]

# %% [markdown]
# ### **LATER, find out what columns have [] in the list of code column - these prompts gave the no-code solution to prompts!!!!**
#
# ## 11/13/2023 Documentation #1
#
# ### Data Collection and Transformation
# 1. The snapshot chosen from the given list of snapshots is **snapshot_20230831**.
# 2. There are 6 different json files in this snapshot. They are - PR sharings, Issue Sharings, Discussion Sharings, Commit Sharings, File Sharings and HN Sharings.
# 3. The columns - Prompt, Answer, List of Code is extracted from ChatgptSharing column of every json file. An extra column called Type which specifed which of the 6 different types the rows come under is created.
# 4. All the 6 json files (extracted and shrunk down) are merged together.
#
# ### Data Cleaning
# 1. Null values are identified in the merged file.
# 2. These null values are then dropped.

# %%
num27353 =  data1["Prompt"][2]
num27353
# Out:
# 'Explain the difference between imperative and declarative programming. Add example on javascript'

# %%
def read_and_preprocess_text(text):
    # Tokenize the text into sentences
    sentences = nltk.sent_tokenize(text)

    # Tokenize each sentence into words, remove stopwords and punctuation, and convert to lowercase
    stop_words = set(nltk.corpus.stopwords.words('english') + list(string.punctuation))
    tokenized_sentences = [
        [word.lower() for word in nltk.word_tokenize(sentence) if word.isalnum() and word.lower() not in stop_words]
        for sentence in sentences
    ]

    return tokenized_sentences

def calculate_cosine_similarity(tfidf_matrix):
    # Calculate cosine similarity between sentences based on TF-IDF matrix
    similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)
    return similarity_matrix

def generate_summary(text, num_sentences=3):
    # Preprocess the text
    tokenized_sentences = read_and_preprocess_text(text)

    # Convert sentences to TF-IDF matrix
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([' '.join(sentence) for sentence in tokenized_sentences])

    # Calculate cosine similarity matrix
    similarity_matrix = calculate_cosine_similarity(tfidf_matrix)

    # Use the PageRank algorithm to rank sentences
    graph = nx.from_numpy_array(similarity_matrix)
    scores = nx.pagerank(graph)

    # Sort sentences by their scores and select the top ones
    ranked_sentences = sorted(((scores[i], sentence) for i, sentence in enumerate(tokenized_sentences)), reverse=True)
    summary_sentences = [sentence for score, sentence in ranked_sentences[:num_sentences]]

    # Join the summary sentences to form the final summary
    summary = ' '.join([' '.join(sentence) for sentence in summary_sentences])

    return summary

# Example usage
text = 'I have a vue 3 application. I have a ref constant which is a list. When nothing changed to the ref for 3 seconds, I want to trigger a method. What do I need?'

summary = generate_summary(text, num_sentences=3)
print(summary)
# Out:
# vue 3 application ref constant list need
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\srini\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\srini\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
generate_summary(num27353, num_sentences=1)
# Out:
# 'explain difference imperative declarative programming'

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Ensure NLTK components are downloaded
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')

# Prompt text
text = "Explain the difference between imperative and declarative programming. Add example on javascript."

# Tokenize the text
tokens = word_tokenize(text)

# Part-of-Speech Tagging
tagged = nltk.pos_tag(tokens)

# Define a list of relevant keywords and part of speeches
relevant_pos = ['VB', 'VBP', 'VBZ', 'VBD', 'VBN', 'VBG']  # Verb forms
relevant_keywords = ['explain', 'demonstrate', 'show', 'prove', 'write code', 'generate', 'example']

# Filter based on POS and custom keywords
keywords = [word for word, pos in tagged if pos in relevant_pos and word.lower() in relevant_keywords]

print(keywords)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\srini\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\srini\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\srini\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['Explain']
